# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
#folder = lambda x: f'/home/charles/Laufer/Lobster_embryo_scripts/Lobster_embryo_2017_{x}_data .csv'

# %%
path = lambda X: f'/home/charles/Laufer/Lobster_embryo_scripts/Lobster_embryo_2017_{X}_data .csv'
data = lambda X: pd.read_csv(path(X))
trials = ['BPA', 'C3', 'Control']

BPA, C3, Control = list(map(data, trials))
BPA[]

# %%
BPA['Additive_Volume'] = pd.Series
ng3_bol = BPA.Trial.str.contains('3ng')
BPA.iloc[ng3_bol]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-2a75b1a5a49f> in <module>
#       1 BPA['Additive_Volume'] = pd.Series
#       2 ng3_bol = BPA.Trial.str.contains('3ng')
# ----> 3 BPA.iloc[ng3_bol]
#
# ~/miniconda3/envs/ML/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/miniconda3/envs/ML/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2083             key = np.asarray(key)
#    2084
# -> 2085         if com.is_bool_indexer(key):
#    2086             self._validate_key(key, axis)
#    2087             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
BPA['Additive_Volume'] = pd.Series()

BPA.query("'3ng' in ")


vol_bol = lambda x: BPA.Trial.str.contains(x)
ng1, ng3, ng5 = list(map(vol_bol, ['1ng', '3ng', '5ng']))
BPA.Additive_Volume[ng1] = 1
BPA.Additive_Volume[ng3] = 3
BPA.Additive_Volume[ng5] = 5
BPA



In [74]: iris.assign(sepal_ratio = lambda x: (x['SepalWidth'] /
   ....:                                      x['SepalLength'])).head()
# Out:
# /home/charles/miniconda3/envs/ML/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-7be639f5d9f6> in <module>
#       2 vol_bol = lambda x: BPA.Trial.str.contains(x)
#       3 ng1, ng3, ng5 = list(map(vol_bol, ['1ng', '3ng', '5ng']))
# ----> 4 BPA.Additive_Volume[ng1] = 1
#       5 BPA.Additive_Volume[ng3] = 3
#       6 BPA.Additive_Volume[ng5] = 5
#
# ~/miniconda3/envs/ML/lib/python3.6/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#     937         # do the setitem
# ...

# %%
BPA['Additive'] = pd.Series(['BPA'] * len(BPA))
BPA['Additive_Volume'] = pd.Series()
BPA.Additive['3ng' in BPA.Trial] = 3
BPA
# Out:
# /home/charles/miniconda3/envs/ML/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/ML/lib/python3.6/site-packages/pandas/core/series.py in _set_with_engine(self, key, value)
#     945         try:
# --> 946             self.index._engine.set_value(values, key, value)
#     947             return
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
BPA
# Out:
#     Tray  Cube  S3_date SurvivED    Trial  Start_date Lobster  \
# 0     T1     1     27.0        T  BPA_3ng         8.0      L9
# 1     T1     2      0.0        E  BPA_3ng         8.0      L9
# 2     T1     3     27.0        T  BPA_3ng         8.0      L9
# 3     T1     4      0.0        E  BPA_3ng         8.0      L9
# 4     T1     5      0.0        E  BPA_3ng         8.0      L9
# 5     T1     6     27.0        T  BPA_3ng         8.0      L9
# 6     T1     7     24.0        E  BPA_3ng         8.0      L9
# 7     T1     8     27.0        F  BPA_3ng         8.0      L9
# 8     T1     9      0.0        E  BPA_3ng         8.0      L9
# 9     T1    10     24.0        F  BPA_3ng         8.0      L9
# 10    T1    11     27.0        E  BPA_3ng         8.0      L9
# 11    T1    12      0.0        E  BPA_3ng         8.0      L9
# 12    T1    13      0.0        F  BPA_3ng         8.0      L9
# 13    T1    14     27.0        E  BPA_3ng         8.0      L9
# ...

# %%
C3
# Out:
#     Tray  Cube  S3_days   Trial
# 0    T33     1        0  C3_3ng
# 1    T33     2        0  C3_3ng
# 2    T33     3        8  C3_3ng
# 3    T33     4        8  C3_3ng
# 4    T33     5        0  C3_3ng
# 5    T33     6        0  C3_3ng
# 6    T33     7        0  C3_3ng
# 7    T33     8        8  C3_3ng
# 8    T33     9        0  C3_3ng
# 9    T33    10        8  C3_3ng
# 10   T33    11        0  C3_3ng
# 11   T33    12        0  C3_3ng
# 12   T33    13        8  C3_3ng
# 13   T33    14        0  C3_3ng
# 14   T33    15        0  C3_3ng
# 15   T33    16        0  C3_3ng
# 16   T28     1        0  C3_3ng
# 17   T28     2        0  C3_3ng
# 18   T28     3        0  C3_3ng
# 19   T28     4        0  C3_3ng
# 20   T28     5        0  C3_3ng
# 21   T28     6        0  C3_3ng
# 22   T28     7        8  C3_3ng
# 23   T28     8        0  C3_3ng
# 24   T28     9        0  C3_3ng
# 25   T28    10        0  C3_3ng
# 26   T28    11        8  C3_3ng
# 27   T28    12        0  C3_3ng
# ...

# %%
Control
# Out:
#     Unnamed: 0  days to molt total embryos
# 0            0            14       n = 310
# 1            1            14       n = 310
# 2            2            14       n = 310
# 3            3            13       n = 310
# 4            4            13       n = 310
# 5            5            10       n = 310
# 6            6            10       n = 310
# 7            7            12       n = 310
# 8            8            16       n = 310
# 9            9            16       n = 310
# 10          10            16       n = 310
# 11          11            16       n = 310
# 12          12            16       n = 310
# 13          13            16       n = 310
# 14          14            15       n = 310
# 15          15            13       n = 310
# 16          16            13       n = 310
# 17          17            13       n = 310
# 18          18            10       n = 310
# 19          19            13       n = 310
# 20          20            13       n = 310
# ...
